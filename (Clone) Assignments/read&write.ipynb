# %%
#read csv
df_csv = spark.read.format("csv").option("header", "true").load("dbfs:/Volumes/practice1/test/employee/employees.csv")
#df.show()
# Or using the / path
df_csv = spark.read.csv("/Volumes/practice1/test/employee/employees.csv", header=True, inferSchema=True)
display(df_csv)

# %%
#read parquet
df_parq= spark.read.parquet("/Volumes/practice1/test/motor_car_trend")
display(df_parq)

# %%
#write to parquet
df_csv.write.parquet("/Volumes/practice1/test/employee/employees.parquet",mode = "overwrite")

# %%
df_parq.write.csv("/Volumes/practice1/test/motor_car_trend/motor_car.csv", header=True, mode="overwrite")
