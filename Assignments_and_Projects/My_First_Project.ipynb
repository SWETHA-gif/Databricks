# %%
displayTable = spark.table("leads_100000")
displayTable.show()

# %%
display(displayTable)

# %%
# %sql
select `Account Id`, `First Name`, `Last Name`, `Email 1` from leads_100000

# %%
# %sql
select * from leads_100000
where `Deal Stage` = "Closed Won" AND `Source` = "Podcast" AND `Lead Owner` = "Madison Mahoney" ;
